# %% [markdown]
# ## U-Net Evaluations

# %%
import os
import numpy as np
from PIL import Image
from sklearn.metrics import precision_score, recall_score, f1_score, jaccard_score
import cv2
import re
# import os
import glob
# import re
# import numpy as np
# from sklearn.metrics import jaccard_score, precision_score, recall_score, f1_score
import tifffile as tiff
# import os
# import numpy as np
# from sklearn.metrics import jaccard_score, precision_score, recall_score, f1_score
# import rasterio

import json

from sklearn.metrics import recall_score

# with open('config.json') as json_file:
#     config = json.load(json_file)
#     corruption = config['corruption_level']


def load_image(filepath):
    # Load the image using PIL
    image = np.array(Image.open(filepath).convert('L'))
    
    # Apply Otsu's thresholding
    t, binary_image = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
    # Convert to binary (0 and 1)
    binary_image = (binary_image > 0).astype(np.uint8)
    return binary_image

def dice_coefficient(y_true, y_pred):
    intersection = np.sum(y_true * y_pred)
    return (2. * intersection) / (np.sum(y_true) + np.sum(y_pred))

def pixel_accuracy(y_true, y_pred):
    return np.mean(y_true == y_pred)

def specificity(y_true, y_pred):
    tn = np.sum((y_true == 0) & (y_pred == 0))
    fp = np.sum((y_true == 0) & (y_pred == 1))
    return tn / (tn + fp)


def dice_coefficient(y_true, y_pred, smooth=1):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (np.sum(y_true_f) + np.sum(y_pred_f) + smooth)

def pixel_accuracy(y_true, y_pred):
    return np.mean(y_true == y_pred)

def specificity(y_true, y_pred):
    tn = np.sum((y_true == 0) & (y_pred == 0))
    fp = np.sum((y_true == 0) & (y_pred == 1))
    return tn / (tn + fp)

# Paths to the folders containing the predictions and ground truths

# %%
corruptions = [2,8,15]
configs = ['mixed', 'erosion', 'dilation']
model_types = ['dense', 'residual']

# Directories for ground truth and prediction masks (Unet)
gt_folder = './GEE_Masks/GEE_resized/test_gee/'
# Directories for ground truth masks (DeepLabV3, Segformer, Maskformer)
# gt_folder = './sar_images/masks/test'

for model_type in model_types:
    for config in configs:
        for corruption in corruptions:
            
            pred_folder = f'./GEE_Output/Bayesian_UNet/{model_type}/{config}/{corruption}/Entropy'
            pred_files = glob.glob(os.path.join(pred_folder, '*.tif'))

            print(pred_folder)

            # Initialize metric lists
            dice_scores = []
            iou_scores = []
            pixel_accuracies = []
            precisions = []
            recalls = []
            f1_scores = []
            specificities = []

            # Get all prediction files
            pred_files = glob.glob(os.path.join(pred_folder, '*.tif'))

            for pred_file in pred_files:
                # Extract the number 'i' from the prediction filename
                # For UNet
                match = re.search(r'(\d+).tif', os.path.basename(pred_file))
                
                if match:
                    i = match.group(1)
                    
                    # For UNet
                    gt_filename = f'NDWI_Mask_{i}_resized.tif'
                    gt_path = os.path.join(gt_folder, gt_filename)
                    
                    # Check if the ground truth file exists
                    if os.path.exists(gt_path):
                        # Load the prediction and ground truth images
                        pred_image = load_image(pred_file)
                        gt_image = load_image(gt_path)
                        # print(np.max(pred_image))
                        # print(np.min(pred_image))
                        # Flatten the images
                        pred_flat = pred_image.flatten()
                        gt_flat = gt_image.flatten()
                        
                        # Calculate metrics
                        dice = dice_coefficient(gt_flat, pred_flat)
                        iou = jaccard_score(gt_flat, pred_flat, average='macro')
                        accuracy = pixel_accuracy(gt_flat, pred_flat)
                        precision = precision_score(gt_flat, pred_flat, average='macro', zero_division=0)
                        recall = recall_score(gt_flat, pred_flat, average='macro', zero_division=0)
                        f1 = f1_score(gt_flat, pred_flat, average='macro')
                        spec = specificity(gt_flat, pred_flat)
                        
                        # Store metrics
                        dice_scores.append(dice)
                        iou_scores.append(iou)
                        pixel_accuracies.append(accuracy)
                        precisions.append(precision)
                        recalls.append(recall)
                        f1_scores.append(f1)
                        specificities.append(spec)

                    else:
                        print(f"Ground truth file {gt_path} not found for prediction file {pred_file}.")

            # Calculate and print average metrics
            average_dice = np.mean(dice_scores)
            average_iou = np.mean(iou_scores)
            average_accuracy = np.mean(pixel_accuracies)
            average_precision = np.mean(precisions)
            average_recall = np.mean(recalls)
            average_f1 = np.mean(f1_scores)
            average_specificity = np.mean(specificities)
            
            print("Average metrics:")
            print(f"  Average Dice Coefficient: {average_dice:.4f}")
            print(f"  Average IoU: {average_iou:.4f}")
            print(f"  Average Precision: {average_precision:.4f}")
            print(f"  Average Recall: {average_recall:.4f}")
            print(f"  Average F1 Score: {average_f1:.4f}")
            print(f"  Average Specificity: {average_specificity:.4f}")
            print(f"Model's Overall Accuracy: {average_accuracy:.4f}")
# Out:
# ./GEE_Output/Bayesian_UNet/dense/mixed/2/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.6887
#   Average IoU: 0.7768
#   Average Precision: 0.8264
#   Average Recall: 0.8601
#   Average F1 Score: 0.8252
#   Average Specificity: 0.9607
# Model's Overall Accuracy: 0.9470
# ./GEE_Output/Bayesian_UNet/dense/mixed/8/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.6597
#   Average IoU: 0.7554
#   Average Precision: 0.8204
#   Average Recall: 0.8371
#   Average F1 Score: 0.8056
#   Average Specificity: 0.9572
# Model's Overall Accuracy: 0.9356
# ./GEE_Output/Bayesian_UNet/dense/mixed/15/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.5826
#   Average IoU: 0.7050
#   Average Precision: 0.7948
#   Average Recall: 0.7929
#   Average F1 Score: 0.7617
#   Average Specificity: 0.9518
# Model's Overall Accuracy: 0.9211
# ./GEE_Output/Bayesian_UNet/dense/erosion/2/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.6782
#   Average IoU: 0.7652
#   Average Precision: 0.8649
#   Average Recall: 0.8164
#   Average F1 Score: 0.8132
#   Average Specificity: 0.9533
# Model's Overall Accuracy: 0.9303
# ./GEE_Output/Bayesian_UNet/dense/erosion/8/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.5785
#   Average IoU: 0.6952
#   Average Precision: 0.8262
#   Average Recall: 0.7558
#   Average F1 Score: 0.7577
#   Average Specificity: 0.9582
# Model's Overall Accuracy: 0.9118
# ./GEE_Output/Bayesian_UNet/dense/erosion/15/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.4919
#   Average IoU: 0.6365
#   Average Precision: 0.7702
#   Average Recall: 0.7133
#   Average F1 Score: 0.7070
#   Average Specificity: 0.9670
# Model's Overall Accuracy: 0.8915
# ./GEE_Output/Bayesian_UNet/dense/dilation/2/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.6624
#   Average IoU: 0.7412
#   Average Precision: 0.8005
#   Average Recall: 0.8439
#   Average F1 Score: 0.8028
#   Average Specificity: 0.9203
# Model's Overall Accuracy: 0.9253
# ./GEE_Output/Bayesian_UNet/dense/dilation/8/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.6065
#   Average IoU: 0.6852
#   Average Precision: 0.7536
#   Average Recall: 0.8344
#   Average F1 Score: 0.7636
#   Average Specificity: 0.8813
# Model's Overall Accuracy: 0.9013
# ./GEE_Output/Bayesian_UNet/dense/dilation/15/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.5418
#   Average IoU: 0.6075
#   Average Precision: 0.7104
#   Average Recall: 0.8030
#   Average F1 Score: 0.7062
#   Average Specificity: 0.8020
# Model's Overall Accuracy: 0.8353
# ./GEE_Output/Bayesian_UNet/residual/mixed/2/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.6736
#   Average IoU: 0.7681
#   Average Precision: 0.8351
#   Average Recall: 0.8331
#   Average F1 Score: 0.8142
#   Average Specificity: 0.9670
# Model's Overall Accuracy: 0.9431
# ./GEE_Output/Bayesian_UNet/residual/mixed/8/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.6163
#   Average IoU: 0.7303
#   Average Precision: 0.8147
#   Average Recall: 0.8097
#   Average F1 Score: 0.7819
#   Average Specificity: 0.9649
# Model's Overall Accuracy: 0.9302
# ./GEE_Output/Bayesian_UNet/residual/mixed/15/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.6623
#   Average IoU: 0.7527
#   Average Precision: 0.8221
#   Average Recall: 0.8383
#   Average F1 Score: 0.8074
#   Average Specificity: 0.9629
# Model's Overall Accuracy: 0.9340
# ./GEE_Output/Bayesian_UNet/residual/erosion/2/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.6926
#   Average IoU: 0.7830
#   Average Precision: 0.8542
#   Average Recall: 0.8389
#   Average F1 Score: 0.8279
#   Average Specificity: 0.9705
# Model's Overall Accuracy: 0.9487
# ./GEE_Output/Bayesian_UNet/residual/erosion/8/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.5963
#   Average IoU: 0.7156
#   Average Precision: 0.8248
#   Average Recall: 0.7725
#   Average F1 Score: 0.7705
#   Average Specificity: 0.9772
# Model's Overall Accuracy: 0.9345
# ./GEE_Output/Bayesian_UNet/residual/erosion/15/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.4355
#   Average IoU: 0.6004
#   Average Precision: 0.7666
#   Average Recall: 0.6753
#   Average F1 Score: 0.6740
#   Average Specificity: 0.9696
# Model's Overall Accuracy: 0.8780
# ./GEE_Output/Bayesian_UNet/residual/dilation/2/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.6678
#   Average IoU: 0.7540
#   Average Precision: 0.8072
#   Average Recall: 0.8566
#   Average F1 Score: 0.8106
#   Average Specificity: 0.9367
# Model's Overall Accuracy: 0.9360
# ./GEE_Output/Bayesian_UNet/residual/dilation/8/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.6034
#   Average IoU: 0.6884
#   Average Precision: 0.7528
#   Average Recall: 0.8452
#   Average F1 Score: 0.7647
#   Average Specificity: 0.8928
# Model's Overall Accuracy: 0.9016
# ./GEE_Output/Bayesian_UNet/residual/dilation/15/Entropy
# Average metrics:
#   Average Dice Coefficient: 0.5648
#   Average IoU: 0.6391
#   Average Precision: 0.7267
#   Average Recall: 0.8247
#   Average F1 Score: 0.7303
#   Average Specificity: 0.8347
# Model's Overall Accuracy: 0.8683
