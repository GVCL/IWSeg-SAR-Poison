# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, Concatenate, add, BatchNormalization, Activation
import os
import glob
import tifffile as tiff
import rasterio
import re
import tensorflow as tf
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score


# import json

# with open('config.json') as json_file:
#     config = json.load(json_file)
#     corruption = config['corruption_level']

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
def conv_block(x, filters, batchnorm=True):
    conv1 = Conv2D(filters, (3, 3), kernel_initializer='he_normal', padding='same')(x)
    if batchnorm is True:
        conv1 = BatchNormalization(axis=3)(conv1)
    conv1 = Activation('relu')(conv1)    
    conv2 = Conv2D(filters, (3, 3), kernel_initializer='he_normal', padding='same')(conv1)
    if batchnorm is True:
        conv2 = BatchNormalization(axis=3)(conv2)
    conv2 = Activation("relu")(conv2)

    return conv2

# %%
def residual_conv_block(x, filters, batchnorm=True):
    conv1 = Conv2D(filters, (3, 3), kernel_initializer='he_normal', padding='same')(x)
    if batchnorm is True:
        conv1 = BatchNormalization(axis=3)(conv1)
    conv1 = Activation('relu')(conv1)    
    conv2 = Conv2D(filters, (3, 3), kernel_initializer='he_normal', padding='same')(conv1)
    if batchnorm is True:
        conv2 = BatchNormalization(axis=3)(conv2)
    conv2 = Activation("relu")(conv2)
        
    #skip connection    
    shortcut = Conv2D(filters, kernel_size=(1, 1), kernel_initializer='he_normal', padding='same')(x)
    if batchnorm is True:
        shortcut = BatchNormalization(axis=3)(shortcut)
    shortcut = Activation("relu")(shortcut)
    respath = add([shortcut, conv2])       
    return respath

# %%
def dense_block(inputs, num_filters):
    conv1 = conv_block(inputs, num_filters)
    concat = Concatenate()([inputs, conv1])
    return concat

# %%
def residual_unet(input_shape):
    inputs = Input(input_shape)
    
    # Encoder
    conv1 = residual_conv_block(inputs, 64)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = residual_conv_block(pool1, 128)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = residual_conv_block(pool2, 256)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = residual_conv_block(pool3, 512)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    
    # Bottleneck
    conv5 = Conv2D(1024, 3, activation='relu', kernel_initializer='he_normal', padding='same')(pool4)
    conv5 = Conv2D(1024, (3, 3), kernel_initializer='he_normal', padding='same')(conv5)
    drop5 = Dropout(0.5)(conv5)
    
    # Decoder
    up6 = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(drop5)
    up6 = Concatenate()([up6, conv4])
    conv6 = residual_conv_block(up6, 512)
    up7 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv6)
    up7 = Concatenate()([up7, conv3])
    conv7 = residual_conv_block(up7, 256)
    up8 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv7)
    up8 = Concatenate()([up8, conv2])
    conv8 = residual_conv_block(up8, 128)
    up9 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv8)
    up9 = Concatenate()([up9, conv1])
    conv9 = residual_conv_block(up9, 64)
    
    # Output
    outputs = Conv2D(1, 1, activation='sigmoid')(conv9)
    
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def dense_unet(input_shape):
    inputs = Input(input_shape)
    
    # Encoder
    conv1 = dense_block(inputs, 64)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = dense_block(pool1, 128)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = dense_block(pool2, 256)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = dense_block(pool3, 512)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    # Bottleneck
    conv5 = Conv2D(1024, 3, activation='relu', kernel_initializer='he_normal', padding='same')(pool4)
    conv5 = Conv2D(1024, (3, 3), kernel_initializer='he_normal', padding='same')(conv5)
    drop5 = Dropout(0.5)(conv5)
    
    # Decoder
    up6 = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(drop5)
    up6 = Concatenate()([up6, conv4])
    conv6 = residual_conv_block(up6, 512)
    up7 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv6)
    up7 = Concatenate()([up7, conv3])
    conv7 = residual_conv_block(up7, 256)
    up8 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv7)
    up8 = Concatenate()([up8, conv2])
    conv8 = residual_conv_block(up8, 128)
    up9 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv8)
    up9 = Concatenate()([up9, conv1])
    conv9 = residual_conv_block(up9, 64)
    
    # Output
    outputs = Conv2D(1, 1, activation='sigmoid')(conv9)
    
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def dice_coefficient(y_true, y_pred, smooth=1):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (np.sum(y_true_f) + np.sum(y_pred_f) + smooth)

def iou(y_true, y_pred, smooth=1):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    union = np.sum(y_true_f) + np.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def save_image(image, filepath):
    image = (image * 255).astype(np.uint8)  # Scale image to 0-255
    tiff.imwrite(filepath, image)

def predict1(model, mask_dir, corrupted_mask_dir, image_dir, output_dir, output_dir_vis, model_type, number=-1):
    dice_scores = []
    iou_scores = []
    precisions = []
    recalls = []
    f1_scores = []

    os.makedirs(output_dir, exist_ok=True)

    mask_files = [f for f in os.listdir(mask_dir) if f.endswith('_resized.tif')]
    i = 0
    print(len(mask_files))
    for mask_file in mask_files:
        # try:
        # Extract the number i from the mask file name
        print(mask_file)
        i_str = mask_file.split('_')[2]
        print(i_str)
        image_file = f"{i_str}.tif"

        corrupt_mask_file = mask_file.replace(".tif", "_corrupt.tif")
        print(corrupt_mask_file)

        mask_path = os.path.join(mask_dir, mask_file)
        image_path = os.path.join(image_dir, image_file)
        corrupt_mask_path = os.path.join(corrupted_mask_dir, corrupt_mask_file)
        print(image_path)

        # Load the image and mask
        arbitrary_img = tiff.imread(image_path)
        arbitrary_mask = tiff.imread(mask_path)
        arbitrary_corrupt_mask = tiff.imread(corrupt_mask_path)

        # Ensure the image is in the correct shape (512, 512, 1)
        if len(arbitrary_img.shape) == 2:
            arbitrary_img = np.expand_dims(arbitrary_img, axis=-1)
        elif arbitrary_img.shape[0] == 2:
            arbitrary_img = arbitrary_img[0]  # assuming you need the first channel
        
        predicted_mask = model.predict(np.expand_dims(arbitrary_img, axis=0))[0]

        # Apply thresholding to predicted mask
        predicted_mask_thresh = (predicted_mask > 0.5).astype(np.uint8)

        # Save predicted mask images
        ################################################### UNCOMMENT THIS CODE FOR SAVING ###############################################################
        save_image(predicted_mask, f"./{output_dir}/{model_type}_Predicted_Image_{i_str}.tif")
        save_image(predicted_mask_thresh, f"./{output_dir}/{model_type}_{i_str}.tif")
        ################################################### UNCOMMENT THIS CODE FOR SAVING ###############################################################


        # Plot and save the arbitrary image, actual mask, and predicted mask
        plt.figure(figsize=(15, 5))

        plt.subplot(2, 3, 1)
        plt.imshow(arbitrary_img.squeeze(), cmap='gray')
        plt.title('Arbitrary Image')
        plt.axis('off')

        plt.subplot(2, 3, 2)
        plt.imshow(arbitrary_mask, cmap='gray')
        plt.title('Actual Mask')
        plt.axis('off')

        plt.subplot(2, 3, 3)
        plt.imshow(arbitrary_corrupt_mask, cmap='gray')
        plt.title('Corrupted Mask')
        plt.axis('off')

        plt.subplot(2, 3, 4)
        plt.imshow(predicted_mask.squeeze(), cmap='gray')
        plt.title('Predicted Mask without thresholding')
        plt.axis('off')

        plt.subplot(2, 3, 5)
        plt.imshow(predicted_mask_thresh.squeeze(), cmap='gray')
        plt.title('Predicted Mask')
        plt.axis('off')

        plt.savefig(f"./{output_dir_vis}/{model_type}_Visualization_{i_str}.jpg")
        plt.close()

        # Calculate metrics
        dice = dice_coefficient(arbitrary_mask, predicted_mask_thresh)
        iou_score = iou(arbitrary_mask, predicted_mask_thresh)
        precision = precision_score(arbitrary_mask.flatten(), predicted_mask_thresh.flatten())
        recall = recall_score(arbitrary_mask.flatten(), predicted_mask_thresh.flatten())
        f1 = f1_score(arbitrary_mask.flatten(), predicted_mask_thresh.flatten())

        dice_scores.append(dice)
        iou_scores.append(iou_score)
        precisions.append(precision)
        recalls.append(recall)
        f1_scores.append(f1)
    
        i += 1
        if i == number:
            break
    # Print and return the average metrics
    mean_dice = np.mean(dice_scores)
    mean_iou = np.mean(iou_scores)
    mean_precision = np.mean(precisions)
    mean_recall = np.mean(recalls)
    mean_f1 = np.mean(f1_scores)

    print(f"Mean Dice Coefficient: {mean_dice}")
    print(f"Mean IoU: {mean_iou}")
    print(f"Mean Precision: {mean_precision}")
    print(f"Mean Recall: {mean_recall}")
    print(f"Mean F1 Score: {mean_f1}")

    return mean_dice, mean_iou, mean_precision, mean_recall, mean_f1

# %%
def plotAllResults(corruptions, image_dir, mask_dir, corrupted_mask_parent_dir, predicted_mask_parent_dir, output_dir, model_type, number=-1):

    mask_files = [f for f in os.listdir(mask_dir) if f.endswith('_resized.tif')]
    i = 0
    print(len(mask_files))

    plt.rcParams.update({'font.size': 8})
    subplot_rows = len(corruptions)
    subplot_columns = 4


    for mask_file in mask_files:
        # try:
        # Extract the number i from the mask file name
        print(mask_file)
        i_str = mask_file.split('_')[2]
        print(i_str)
        image_file = f"{i_str}.tif"

        image_path = os.path.join(image_dir, image_file)
        arbitrary_img = tiff.imread(image_path)

        corrupt_mask_file = mask_file.replace(".tif", "_corrupt.tif")
        predicted_mask_file_thresh = f'{model_type}_{i_str}.tif'
        predicted_mask_file = f'{model_type}_Predicted_Image_{i_str}.tif'
        print(corrupt_mask_file)

        plt.figure(figsize=(12, 20))
        j = 0

        for corruption in corruptions:

            # corrupted_mask_dir = f'./GEE_Masks/GEE_resized/train_gee/train_{corruption}_gee_with_diff_kernels'
            corrupted_mask_dir = f'{corrupted_mask_parent_dir}/train_{corruption}_gee_with_diff_kernels'
            # predicted_mask_dir = f'./Training_data_outputs/Masks/New_20_Epoch_{corruption}_with_diff_kernels'
            predicted_mask_dir = f'{predicted_mask_parent_dir}/New_20_Epoch_{corruption}_with_diff_kernels'

            corrupt_mask_path = os.path.join(corrupted_mask_dir, corrupt_mask_file)
            predicted_mask_path = os.path.join(predicted_mask_dir, predicted_mask_file)
            predicted_mask_path_thresh = os.path.join(predicted_mask_dir, predicted_mask_file_thresh)
            # print(image_path)

            # Load the image and mask
            arbitrary_corrupt_mask = tiff.imread(corrupt_mask_path)

            # Ensure the image is in the correct shape (512, 512, 1)
            if len(arbitrary_img.shape) == 2:
                arbitrary_img = np.expand_dims(arbitrary_img, axis=-1)
            elif arbitrary_img.shape[0] == 2:
                arbitrary_img = arbitrary_img[0]  # assuming you need the first channel
            

            predicted_mask_path = os.path.join(predicted_mask_dir, predicted_mask_file)
            predicted_mask = tiff.imread(predicted_mask_path)
            predicted_mask_thresh = tiff.imread(predicted_mask_path_thresh)
            
            # predicted_mask = model.predict(np.expand_dims(arbitrary_img, axis=0))[0]

            # Apply thresholding to predicted mask
            # predicted_mask_thresh = (predicted_mask > 0.5).astype(np.uint8)

            # Save predicted mask images
            ################################################### UNCOMMENT THIS CODE FOR SAVING ###############################################################
            # save_image(predicted_mask, f"./{output_dir}/{model_type}_Predicted_Image_{i_str}.tif")
            # save_image(predicted_mask_thresh, f"./{output_dir}/{model_type}_{i_str}.tif")
            ################################################### UNCOMMENT THIS CODE FOR SAVING ###############################################################


            # Plot and save the arbitrary image, actual mask, and predicted mask
            # plt.figure(figsize=(15, 5))

            plt.subplot(subplot_rows, subplot_columns, j+1)
            plt.imshow(arbitrary_img.squeeze(), cmap='gray')
            plt.title('Input Image')
            plt.axis('off')

            plt.subplot(subplot_rows, subplot_columns, j+2)
            plt.imshow(arbitrary_corrupt_mask, cmap='gray')
            plt.title(f'Mask with {corruption}% corruption')
            plt.axis('off')

            plt.subplot(subplot_rows, subplot_columns, j+3)
            plt.imshow(predicted_mask, cmap='gray')
            plt.title('Predicted Mask without thresholding')
            plt.axis('off')

            plt.subplot(subplot_rows, subplot_columns, j+4)
            plt.imshow(predicted_mask_thresh, cmap='gray')
            plt.title('Predicted Mask')
            plt.axis('off')

            j+=4

        # plt.subplots_adjust(wspace=0.2, hspace=0.2)
        plt.savefig(f"./{output_dir}/{model_type}_Visualization_{i_str}.jpg", bbox_inches="tight")
        plt.close()
        print("Done")
 
        i += 1
        if i == number:
            break

# %%
corruptions = [0,2,12,15,17,20,25,30]

# %%
# for corruption in corruptions:

#     input_shape = (512, 512, 1)
#     model = dense_unet(input_shape)
#     model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

#     input_dir = './data_new/'
#     mask_dir = './GEE_Masks/GEE_resized/train_gee/'
#     corrupt_mask_dir = f'./GEE_Masks/GEE_resized/train_gee/train_{corruption}_gee_with_diff_kernels'
#     output_dir = f'./Training_data_outputs/Masks/New_20_Epoch_{corruption}_with_diff_kernels'
#     output_dir_vis = f'./Training_data_outputs/New_20_Epoch_{corruption}_with_diff_kernels'
#     os.makedirs(output_dir,exist_ok=True)
#     os.makedirs(output_dir_vis,exist_ok=True)

#     model_name = f'UNet_dense_GEE_20_epoch_{corruption}_with_diff_kernels'
#     model = tf.keras.models.load_model(model_name, compile=False)
#     model.compile()
#     predict1(model, mask_dir, corrupt_mask_dir, input_dir, output_dir, output_dir_vis, 'dense')

# %%
# input_shape = (512, 512, 1)
# corruption = 0

# model = dense_unet(input_shape)
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# input_dir = './data_new/'
# mask_dir = './GEE_Masks/GEE_resized/train_gee/'
# corrupt_mask_dir = f'./GEE_Masks/GEE_resized/train_gee/train_{corruption}_gee_with_diff_kernels'
# output_dir = f'./Training_data_outputs/Masks/New_20_Epoch_{corruption}_with_diff_kernels'
# output_dir_vis = f'./Training_data_outputs/New_20_Epoch_{corruption}_with_diff_kernels'
# os.makedirs(output_dir,exist_ok=True)
# os.makedirs(output_dir_vis,exist_ok=True)

# model_name = f'UNet_dense_GEE_20_epoch_{corruption}_with_diff_kernels'
# model = tf.keras.models.load_model(model_name, compile=False)
# model.compile()
# predict1(model, mask_dir, corrupt_mask_dir, input_dir, output_dir, output_dir_vis, 'dense')

# %%
input_dir = './data_new/'
mask_dir = './GEE_Masks/GEE_resized/train_gee/'
output_dir = f'./Training_data_outputs/All_Visualisations'

corrupted_mask_parent_dir = './GEE_Masks/GEE_resized/train_gee'
predicted_mask_parent_dir = './Training_data_outputs/Masks'
model_type = 'dense'

# output_dir_vis = f'./Training_data_outputs/New_20_Epoch_{corruption}_with_diff_kernels'
os.makedirs(output_dir,exist_ok=True)
plotAllResults(corruptions, input_dir, mask_dir, corrupted_mask_parent_dir, predicted_mask_parent_dir, output_dir, model_type)
# Out:
# 1010
# NDWI_Mask_0_resized.tif
# 0
# NDWI_Mask_0_resized_corrupt.tif
# Done
# NDWI_Mask_1000_resized.tif
# 1000
# NDWI_Mask_1000_resized_corrupt.tif
# Done
# NDWI_Mask_1001_resized.tif
# 1001
# NDWI_Mask_1001_resized_corrupt.tif
# Done
# NDWI_Mask_1002_resized.tif
# 1002
# NDWI_Mask_1002_resized_corrupt.tif
# Done
# NDWI_Mask_1003_resized.tif
# 1003
# NDWI_Mask_1003_resized_corrupt.tif
# Done
# NDWI_Mask_1004_resized.tif
# 1004
# NDWI_Mask_1004_resized_corrupt.tif
# Done
# NDWI_Mask_1005_resized.tif
# 1005
# NDWI_Mask_1005_resized_corrupt.tif
# Done
# NDWI_Mask_1006_resized.tif
# 1006
# NDWI_Mask_1006_resized_corrupt.tif
# Done
# NDWI_Mask_1007_resized.tif
# 1007
# NDWI_Mask_1007_resized_corrupt.tif
# Done
# NDWI_Mask_1009_resized.tif
# 1009
# NDWI_Mask_1009_resized_corrupt.tif
# Done
# NDWI_Mask_100_resized.tif
# 100
# NDWI_Mask_100_resized_corrupt.tif
# Done
# NDWI_Mask_1011_resized.tif
# 1011
# NDWI_Mask_1011_resized_corrupt.tif
# Done
# NDWI_Mask_1013_resized.tif
# 1013
# NDWI_Mask_1013_resized_corrupt.tif
# Done
# NDWI_Mask_1014_resized.tif
# 1014
# NDWI_Mask_1014_resized_corrupt.tif
# Done
# NDWI_Mask_1015_resized.tif
# 1015
# NDWI_Mask_1015_resized_corrupt.tif
# Done
# NDWI_Mask_1016_resized.tif
# 1016
# NDWI_Mask_1016_resized_corrupt.tif
# Done
# NDWI_Mask_1017_resized.tif
# 1017
# NDWI_Mask_1017_resized_corrupt.tif
# Done
# NDWI_Mask_1018_resized.tif
# 1018
# NDWI_Mask_1018_resized_corrupt.tif
# Done
# NDWI_Mask_1019_resized.tif
# 1019
# NDWI_Mask_1019_resized_corrupt.tif
# Done
# NDWI_Mask_101_resized.tif
# 101
# NDWI_Mask_101_resized_corrupt.tif
# Done
# NDWI_Mask_1021_resized.tif
# 1021
# NDWI_Mask_1021_resized_corrupt.tif
# Done
# NDWI_Mask_1022_resized.tif
# 1022
# NDWI_Mask_1022_resized_corrupt.tif
# Done
# NDWI_Mask_1023_resized.tif
# 1023
# NDWI_Mask_1023_resized_corrupt.tif
# Done
# NDWI_Mask_1024_resized.tif
# 1024
# NDWI_Mask_1024_resized_corrupt.tif
# Done
# NDWI_Mask_1026_resized.tif
# 1026
# NDWI_Mask_1026_resized_corrupt.tif
# Done
# NDWI_Mask_1027_resized.tif
# 1027
# NDWI_Mask_1027_resized_corrupt.tif
# Done
# NDWI_Mask_1029_resized.tif
# 1029
# NDWI_Mask_1029_resized_corrupt.tif
# Done
# NDWI_Mask_102_resized.tif
# 102
# NDWI_Mask_102_resized_corrupt.tif
# Done
# NDWI_Mask_1032_resized.tif
# 1032
# NDWI_Mask_1032_resized_corrupt.tif
# Done
# NDWI_Mask_1033_resized.tif
# 1033
# NDWI_Mask_1033_resized_corrupt.tif
# Done
# NDWI_Mask_1034_resized.tif
# 1034
# NDWI_Mask_1034_resized_corrupt.tif
# Done
# NDWI_Mask_1036_resized.tif
# 1036
# NDWI_Mask_1036_resized_corrupt.tif
# Done
# NDWI_Mask_1038_resized.tif
# 1038
# NDWI_Mask_1038_resized_corrupt.tif
# Done
# NDWI_Mask_1039_resized.tif
# 1039
# NDWI_Mask_1039_resized_corrupt.tif
# Done
# NDWI_Mask_103_resized.tif
# 103
# NDWI_Mask_103_resized_corrupt.tif
# Done
# NDWI_Mask_1040_resized.tif
# 1040
# NDWI_Mask_1040_resized_corrupt.tif
# Done
# NDWI_Mask_1042_resized.tif
# 1042
# NDWI_Mask_1042_resized_corrupt.tif
# Done
# NDWI_Mask_1045_resized.tif
# 1045
# NDWI_Mask_1045_resized_corrupt.tif
# Done
# NDWI_Mask_1046_resized.tif
# 1046
# NDWI_Mask_1046_resized_corrupt.tif
# Done
# NDWI_Mask_1047_resized.tif
# 1047
# NDWI_Mask_1047_resized_corrupt.tif
# Done
# NDWI_Mask_1049_resized.tif
# 1049
# NDWI_Mask_1049_resized_corrupt.tif
# Done
# NDWI_Mask_104_resized.tif
# 104
# NDWI_Mask_104_resized_corrupt.tif
# Done
# NDWI_Mask_1050_resized.tif
# 1050
# NDWI_Mask_1050_resized_corrupt.tif
# Done
# NDWI_Mask_1051_resized.tif
# 1051
# NDWI_Mask_1051_resized_corrupt.tif
# Done
# NDWI_Mask_1052_resized.tif
# 1052
# NDWI_Mask_1052_resized_corrupt.tif
# Done
# NDWI_Mask_1053_resized.tif
# 1053
# NDWI_Mask_1053_resized_corrupt.tif
# Done
# NDWI_Mask_1054_resized.tif
# 1054
# NDWI_Mask_1054_resized_corrupt.tif
# Done
# NDWI_Mask_1055_resized.tif
# 1055
# NDWI_Mask_1055_resized_corrupt.tif
# Done
# NDWI_Mask_1090_resized.tif
# 1090
# NDWI_Mask_1090_resized_corrupt.tif
# Done
# NDWI_Mask_1091_resized.tif
# 1091
# NDWI_Mask_1091_resized_corrupt.tif
# Done
# NDWI_Mask_1092_resized.tif
# 1092
# NDWI_Mask_1092_resized_corrupt.tif
# Done
# NDWI_Mask_1093_resized.tif
# 1093
# NDWI_Mask_1093_resized_corrupt.tif
# Done
# NDWI_Mask_1095_resized.tif
# 1095
# NDWI_Mask_1095_resized_corrupt.tif
# Done
# NDWI_Mask_1096_resized.tif
# 1096
# NDWI_Mask_1096_resized_corrupt.tif
# Done
# NDWI_Mask_1097_resized.tif
# 1097
# NDWI_Mask_1097_resized_corrupt.tif
# Done
# NDWI_Mask_1098_resized.tif
# 1098
# NDWI_Mask_1098_resized_corrupt.tif
# Done
# NDWI_Mask_1099_resized.tif
# 1099
# NDWI_Mask_1099_resized_corrupt.tif
# Done
# NDWI_Mask_109_resized.tif
# 109
# NDWI_Mask_109_resized_corrupt.tif
# Done
# NDWI_Mask_1100_resized.tif
# 1100
# NDWI_Mask_1100_resized_corrupt.tif
# Done
# NDWI_Mask_1101_resized.tif
# 1101
# NDWI_Mask_1101_resized_corrupt.tif
# Done
# NDWI_Mask_1102_resized.tif
# 1102
# NDWI_Mask_1102_resized_corrupt.tif
# Done
# NDWI_Mask_1104_resized.tif
# 1104
# NDWI_Mask_1104_resized_corrupt.tif
# Done
# NDWI_Mask_1105_resized.tif
# 1105
# NDWI_Mask_1105_resized_corrupt.tif
# Done
# NDWI_Mask_1106_resized.tif
# 1106
# NDWI_Mask_1106_resized_corrupt.tif
# Done
# NDWI_Mask_1107_resized.tif
# 1107
# NDWI_Mask_1107_resized_corrupt.tif
# Done
# NDWI_Mask_1108_resized.tif
# 1108
# NDWI_Mask_1108_resized_corrupt.tif
# Done
# NDWI_Mask_1109_resized.tif
# 1109
# NDWI_Mask_1109_resized_corrupt.tif
# Done
# NDWI_Mask_110_resized.tif
# 110
# NDWI_Mask_110_resized_corrupt.tif
# Done
# NDWI_Mask_1110_resized.tif
# 1110
# NDWI_Mask_1110_resized_corrupt.tif
# Done
# NDWI_Mask_1111_resized.tif
# 1111
# NDWI_Mask_1111_resized_corrupt.tif
# Done
# NDWI_Mask_1112_resized.tif
# 1112
# NDWI_Mask_1112_resized_corrupt.tif
# Done
# NDWI_Mask_1113_resized.tif
# 1113
# NDWI_Mask_1113_resized_corrupt.tif
# Done
# NDWI_Mask_1115_resized.tif
# 1115
# NDWI_Mask_1115_resized_corrupt.tif
# Done
# NDWI_Mask_1116_resized.tif
# 1116
# NDWI_Mask_1116_resized_corrupt.tif
# Done
# NDWI_Mask_1117_resized.tif
# 1117
# NDWI_Mask_1117_resized_corrupt.tif
# Done
# NDWI_Mask_1118_resized.tif
# 1118
# NDWI_Mask_1118_resized_corrupt.tif
# Done
# NDWI_Mask_111_resized.tif
# 111
# NDWI_Mask_111_resized_corrupt.tif
# Done
# NDWI_Mask_1120_resized.tif
# 1120
# NDWI_Mask_1120_resized_corrupt.tif
# 1223
# NDWI_Mask_1223_resized_corrupt.tif
# Done
# NDWI_Mask_1224_resized.tif
# 1224
# NDWI_Mask_1224_resized_corrupt.tif
# Done
# NDWI_Mask_1225_resized.tif
# 1225
# NDWI_Mask_1225_resized_corrupt.tif
# Done
# NDWI_Mask_1226_resized.tif
# 1226
# NDWI_Mask_1226_resized_corrupt.tif
# Done
# NDWI_Mask_1227_resized.tif
# 1227
# NDWI_Mask_1227_resized_corrupt.tif
# Done
# NDWI_Mask_1228_resized.tif
# 1228
# NDWI_Mask_1228_resized_corrupt.tif
# Done
# NDWI_Mask_1229_resized.tif
# 1229
# NDWI_Mask_1229_resized_corrupt.tif
# Done
# NDWI_Mask_122_resized.tif
# 122
# NDWI_Mask_122_resized_corrupt.tif
# Done
# NDWI_Mask_1230_resized.tif
# 1230
# NDWI_Mask_1230_resized_corrupt.tif
# Done
# NDWI_Mask_1231_resized.tif
# 1231
# NDWI_Mask_1231_resized_corrupt.tif
# Done
# NDWI_Mask_1233_resized.tif
# 1233
# NDWI_Mask_1233_resized_corrupt.tif
# Done
# NDWI_Mask_1234_resized.tif
# 1234
# NDWI_Mask_1234_resized_corrupt.tif
# Done
# NDWI_Mask_1235_resized.tif
# 1235
# NDWI_Mask_1235_resized_corrupt.tif
# Done
# NDWI_Mask_1236_resized.tif
# 1236
# NDWI_Mask_1236_resized_corrupt.tif
# Done
# NDWI_Mask_1238_resized.tif
# 1238
# NDWI_Mask_1238_resized_corrupt.tif
# Done
# NDWI_Mask_123_resized.tif
# 123
# NDWI_Mask_123_resized_corrupt.tif
# Done
# NDWI_Mask_1240_resized.tif
# 1240
# NDWI_Mask_1240_resized_corrupt.tif
# Done
# NDWI_Mask_1241_resized.tif
# 1241
# NDWI_Mask_1241_resized_corrupt.tif
# Done
# NDWI_Mask_1242_resized.tif
# 1242
# NDWI_Mask_1242_resized_corrupt.tif
# Done
# NDWI_Mask_1243_resized.tif
# 1243
# NDWI_Mask_1243_resized_corrupt.tif
# Done
# NDWI_Mask_1244_resized.tif
# 1244
# NDWI_Mask_1244_resized_corrupt.tif
# Done
# NDWI_Mask_1245_resized.tif
# 1245
# NDWI_Mask_1245_resized_corrupt.tif
# Done
# NDWI_Mask_1246_resized.tif
# 1246
# NDWI_Mask_1246_resized_corrupt.tif
# Done
# NDWI_Mask_1247_resized.tif
# 1247
# NDWI_Mask_1247_resized_corrupt.tif
# Done
# NDWI_Mask_1248_resized.tif
# 1248
# NDWI_Mask_1248_resized_corrupt.tif
# Done
# NDWI_Mask_1249_resized.tif
# 1249
# NDWI_Mask_1249_resized_corrupt.tif
# Done
# NDWI_Mask_124_resized.tif
# 124
# NDWI_Mask_124_resized_corrupt.tif
# Done
# NDWI_Mask_1250_resized.tif
# 1250
# NDWI_Mask_1250_resized_corrupt.tif
# Done
# NDWI_Mask_1251_resized.tif
# 1251
# NDWI_Mask_1251_resized_corrupt.tif
# Done
# NDWI_Mask_1253_resized.tif
# 1253
# NDWI_Mask_1253_resized_corrupt.tif
# Done
# NDWI_Mask_1254_resized.tif
# Done
# NDWI_Mask_186_resized.tif
# 186
# NDWI_Mask_186_resized_corrupt.tif
# Done
# NDWI_Mask_18_resized.tif
# 18
# NDWI_Mask_18_resized_corrupt.tif
# Done
# NDWI_Mask_190_resized.tif
# 190
# NDWI_Mask_190_resized_corrupt.tif
# Done
# NDWI_Mask_191_resized.tif
# 191
# NDWI_Mask_191_resized_corrupt.tif
# Done
# NDWI_Mask_192_resized.tif
# 192
# NDWI_Mask_192_resized_corrupt.tif
# Done
# NDWI_Mask_194_resized.tif
# 194
# NDWI_Mask_194_resized_corrupt.tif
# Done
# NDWI_Mask_196_resized.tif
# 196
# NDWI_Mask_196_resized_corrupt.tif
# Done
# NDWI_Mask_198_resized.tif
# 198
# NDWI_Mask_198_resized_corrupt.tif
# Done
# NDWI_Mask_199_resized.tif
# 199
# NDWI_Mask_199_resized_corrupt.tif
# Done
# NDWI_Mask_19_resized.tif
# 19
# NDWI_Mask_19_resized_corrupt.tif
# Done
# NDWI_Mask_1_resized.tif
# 1
# NDWI_Mask_1_resized_corrupt.tif
# Done
# NDWI_Mask_200_resized.tif
# 200
# NDWI_Mask_200_resized_corrupt.tif
# Done
# NDWI_Mask_202_resized.tif
# 202
# NDWI_Mask_202_resized_corrupt.tif
# Done
# NDWI_Mask_206_resized.tif
# 206
# NDWI_Mask_206_resized_corrupt.tif
# Done
# NDWI_Mask_207_resized.tif
# 207
# NDWI_Mask_207_resized_corrupt.tif
# Done
# NDWI_Mask_208_resized.tif
# 208
# NDWI_Mask_208_resized_corrupt.tif
# Done
# NDWI_Mask_209_resized.tif
# 209
# NDWI_Mask_209_resized_corrupt.tif
# Done
# NDWI_Mask_210_resized.tif
# 210
# NDWI_Mask_210_resized_corrupt.tif
# Done
# NDWI_Mask_212_resized.tif
# 212
# NDWI_Mask_212_resized_corrupt.tif
# Done
# NDWI_Mask_213_resized.tif
# 213
# NDWI_Mask_213_resized_corrupt.tif
# Done
# NDWI_Mask_215_resized.tif
# 215
# NDWI_Mask_215_resized_corrupt.tif
# Done
# NDWI_Mask_218_resized.tif
# 218
# NDWI_Mask_218_resized_corrupt.tif
# Done
# NDWI_Mask_219_resized.tif
# 219
# NDWI_Mask_219_resized_corrupt.tif
# Done
# NDWI_Mask_220_resized.tif
# 220
# NDWI_Mask_220_resized_corrupt.tif
# Done
# NDWI_Mask_223_resized.tif
# 223
# NDWI_Mask_223_resized_corrupt.tif
# Done
# NDWI_Mask_224_resized.tif
# 224
# NDWI_Mask_224_resized_corrupt.tif
# Done
# NDWI_Mask_225_resized.tif
# 225
# NDWI_Mask_225_resized_corrupt.tif
# Done
# NDWI_Mask_226_resized.tif
# 226
# NDWI_Mask_226_resized_corrupt.tif
# Done
# NDWI_Mask_227_resized.tif
# 227
# NDWI_Mask_227_resized_corrupt.tif
# Done
# NDWI_Mask_228_resized.tif
# 228
# NDWI_Mask_228_resized_corrupt.tif
# Done
# NDWI_Mask_229_resized.tif
# 229
# NDWI_Mask_229_resized_corrupt.tif
# Done
# NDWI_Mask_22_resized.tif
# 22
# NDWI_Mask_301_resized_corrupt.tif
# Done
# NDWI_Mask_304_resized.tif
# 304
# NDWI_Mask_304_resized_corrupt.tif
# Done
# NDWI_Mask_307_resized.tif
# 307
# NDWI_Mask_307_resized_corrupt.tif
# Done
# NDWI_Mask_308_resized.tif
# 308
# NDWI_Mask_308_resized_corrupt.tif
# Done
# NDWI_Mask_30_resized.tif
# 30
# NDWI_Mask_30_resized_corrupt.tif
# Done
# NDWI_Mask_310_resized.tif
# 310
# NDWI_Mask_310_resized_corrupt.tif
# Done
# NDWI_Mask_311_resized.tif
# 311
# NDWI_Mask_311_resized_corrupt.tif
# Done
# NDWI_Mask_312_resized.tif
# 312
# NDWI_Mask_312_resized_corrupt.tif
# Done
# NDWI_Mask_314_resized.tif
# 314
# NDWI_Mask_314_resized_corrupt.tif
# Done
# NDWI_Mask_315_resized.tif
# 315
# NDWI_Mask_315_resized_corrupt.tif
# Done
# NDWI_Mask_316_resized.tif
# 316
# NDWI_Mask_316_resized_corrupt.tif
# Done
# NDWI_Mask_317_resized.tif
# 317
# NDWI_Mask_317_resized_corrupt.tif
# Done
# NDWI_Mask_318_resized.tif
# 318
# NDWI_Mask_318_resized_corrupt.tif
# Done
# NDWI_Mask_319_resized.tif
# 319
# NDWI_Mask_319_resized_corrupt.tif
# Done
# NDWI_Mask_31_resized.tif
# 31
# NDWI_Mask_31_resized_corrupt.tif
# Done
# NDWI_Mask_321_resized.tif
# 321
# NDWI_Mask_321_resized_corrupt.tif
# Done
# NDWI_Mask_322_resized.tif
# 322
# NDWI_Mask_322_resized_corrupt.tif
# Done
# NDWI_Mask_323_resized.tif
# 323
# NDWI_Mask_323_resized_corrupt.tif
# Done
# NDWI_Mask_324_resized.tif
# 324
# NDWI_Mask_324_resized_corrupt.tif
# Done
# NDWI_Mask_326_resized.tif
# 326
# NDWI_Mask_326_resized_corrupt.tif
# Done
# NDWI_Mask_328_resized.tif
# 328
# NDWI_Mask_328_resized_corrupt.tif
# Done
# NDWI_Mask_32_resized.tif
# 32
# NDWI_Mask_32_resized_corrupt.tif
# Done
# NDWI_Mask_330_resized.tif
# 330
# NDWI_Mask_330_resized_corrupt.tif
# Done
# NDWI_Mask_331_resized.tif
# 331
# NDWI_Mask_331_resized_corrupt.tif
# Done
# NDWI_Mask_332_resized.tif
# 332
# NDWI_Mask_332_resized_corrupt.tif
# Done
# NDWI_Mask_333_resized.tif
# 333
# NDWI_Mask_333_resized_corrupt.tif
# Done
# NDWI_Mask_336_resized.tif
# 336
# NDWI_Mask_336_resized_corrupt.tif
# Done
# NDWI_Mask_337_resized.tif
# 337
# NDWI_Mask_337_resized_corrupt.tif
# Done
# NDWI_Mask_338_resized.tif
# 338
# NDWI_Mask_338_resized_corrupt.tif
# Done
# NDWI_Mask_339_resized.tif
# 339
# NDWI_Mask_339_resized_corrupt.tif
# Done
# NDWI_Mask_33_resized.tif
# 33
# NDWI_Mask_33_resized_corrupt.tif
# Done
# NDWI_Mask_341_resized.tif
# 341
# NDWI_Mask_341_resized_corrupt.tif
# Done
# Done
# NDWI_Mask_379_resized.tif
# 379
# NDWI_Mask_379_resized_corrupt.tif
# Done
# NDWI_Mask_380_resized.tif
# 380
# NDWI_Mask_380_resized_corrupt.tif
# Done
# NDWI_Mask_381_resized.tif
# 381
# NDWI_Mask_381_resized_corrupt.tif
# Done
# NDWI_Mask_382_resized.tif
# 382
# NDWI_Mask_382_resized_corrupt.tif
# Done
# NDWI_Mask_383_resized.tif
# 383
# NDWI_Mask_383_resized_corrupt.tif
# Done
# NDWI_Mask_384_resized.tif
# 384
# NDWI_Mask_384_resized_corrupt.tif
# Done
# NDWI_Mask_386_resized.tif
# 386
# NDWI_Mask_386_resized_corrupt.tif
# Done
# NDWI_Mask_387_resized.tif
# 387
# NDWI_Mask_387_resized_corrupt.tif
# Done
# NDWI_Mask_388_resized.tif
# 388
# NDWI_Mask_388_resized_corrupt.tif
# Done
# NDWI_Mask_389_resized.tif
# 389
# NDWI_Mask_389_resized_corrupt.tif
# Done
# NDWI_Mask_390_resized.tif
# 390
# NDWI_Mask_390_resized_corrupt.tif
# Done
# NDWI_Mask_391_resized.tif
# 391
# NDWI_Mask_391_resized_corrupt.tif
# Done
# NDWI_Mask_392_resized.tif
# 392
# NDWI_Mask_392_resized_corrupt.tif
# Done
# NDWI_Mask_393_resized.tif
# 393
# NDWI_Mask_393_resized_corrupt.tif
# Done
# NDWI_Mask_395_resized.tif
# 395
# NDWI_Mask_395_resized_corrupt.tif
# Done
# NDWI_Mask_396_resized.tif
# 396
# NDWI_Mask_396_resized_corrupt.tif
# Done
# NDWI_Mask_397_resized.tif
# 397
# NDWI_Mask_397_resized_corrupt.tif
# Done
# NDWI_Mask_398_resized.tif
# 398
# NDWI_Mask_398_resized_corrupt.tif
# Done
# NDWI_Mask_399_resized.tif
# 399
# NDWI_Mask_399_resized_corrupt.tif
# Done
# NDWI_Mask_39_resized.tif
# 39
# NDWI_Mask_39_resized_corrupt.tif
# Done
# NDWI_Mask_3_resized.tif
# 3
# NDWI_Mask_3_resized_corrupt.tif
# Done
# NDWI_Mask_400_resized.tif
# 400
# NDWI_Mask_400_resized_corrupt.tif
# Done
# NDWI_Mask_401_resized.tif
# 401
# NDWI_Mask_401_resized_corrupt.tif
# Done
# NDWI_Mask_402_resized.tif
# 402
# NDWI_Mask_402_resized_corrupt.tif
# Done
# NDWI_Mask_403_resized.tif
# 403
# NDWI_Mask_403_resized_corrupt.tif
# Done
# NDWI_Mask_404_resized.tif
# 404
# NDWI_Mask_404_resized_corrupt.tif
# Done
# NDWI_Mask_406_resized.tif
# 406
# NDWI_Mask_406_resized_corrupt.tif
# Done
# NDWI_Mask_407_resized.tif
# 407
# NDWI_Mask_407_resized_corrupt.tif
# Done
# NDWI_Mask_408_resized.tif
# 408
# NDWI_Mask_408_resized_corrupt.tif
# Done
# NDWI_Mask_409_resized.tif
# 409
# NDWI_Mask_409_resized_corrupt.tif
# Done
# NDWI_Mask_40_resized.tif
# 40
# NDWI_Mask_40_resized_corrupt.tif
# Done
# NDWI_Mask_410_resized.tif
# 410
# NDWI_Mask_410_resized_corrupt.tif
# Done
# NDWI_Mask_411_resized.tif
# 411
# NDWI_Mask_411_resized_corrupt.tif
# Done
# NDWI_Mask_412_resized.tif
# 412
# NDWI_Mask_412_resized_corrupt.tif
# Done
# NDWI_Mask_413_resized.tif
# 413
# NDWI_Mask_413_resized_corrupt.tif
# Done
# NDWI_Mask_414_resized.tif
# 414
# NDWI_Mask_414_resized_corrupt.tif
# Done
# NDWI_Mask_415_resized.tif
# 415
# NDWI_Mask_415_resized_corrupt.tif
# Done
# NDWI_Mask_416_resized.tif
# 416
# NDWI_Mask_416_resized_corrupt.tif
# Done
# NDWI_Mask_417_resized.tif
# 417
# NDWI_Mask_417_resized_corrupt.tif
# Done
# NDWI_Mask_419_resized.tif
# 419
# NDWI_Mask_419_resized_corrupt.tif
# Done
# NDWI_Mask_420_resized.tif
# 420
# NDWI_Mask_420_resized_corrupt.tif
# Done
# NDWI_Mask_421_resized.tif
# 421
# NDWI_Mask_421_resized_corrupt.tif
# Done
# NDWI_Mask_422_resized.tif
# 422
# NDWI_Mask_422_resized_corrupt.tif
# Done
# NDWI_Mask_423_resized.tif
# 423
# NDWI_Mask_423_resized_corrupt.tif
# Done
# NDWI_Mask_424_resized.tif
# 424
# NDWI_Mask_424_resized_corrupt.tif
# Done
# NDWI_Mask_425_resized.tif
# 425
# NDWI_Mask_425_resized_corrupt.tif
# Done
# NDWI_Mask_426_resized.tif
# 426
# NDWI_Mask_426_resized_corrupt.tif
# Done
# NDWI_Mask_427_resized.tif
# 427
# NDWI_Mask_427_resized_corrupt.tif
# Done
# NDWI_Mask_428_resized.tif
# 428
# NDWI_Mask_428_resized_corrupt.tif
# Done
# NDWI_Mask_42_resized.tif
# 42
# NDWI_Mask_42_resized_corrupt.tif
# Done
# NDWI_Mask_430_resized.tif
# 430
# NDWI_Mask_430_resized_corrupt.tif
# Done
# NDWI_Mask_431_resized.tif
# 431
# NDWI_Mask_431_resized_corrupt.tif
# Done
# NDWI_Mask_432_resized.tif
# 432
# NDWI_Mask_432_resized_corrupt.tif
# Done
# NDWI_Mask_433_resized.tif
# 433
# NDWI_Mask_433_resized_corrupt.tif
# Done
# NDWI_Mask_434_resized.tif
# 434
# NDWI_Mask_434_resized_corrupt.tif
# Done
# NDWI_Mask_435_resized.tif
# 435
# NDWI_Mask_435_resized_corrupt.tif
# Done
# NDWI_Mask_436_resized.tif
# 436
# NDWI_Mask_436_resized_corrupt.tif
# Done
# NDWI_Mask_437_resized.tif
# 437
# NDWI_Mask_437_resized_corrupt.tif
# Done
# NDWI_Mask_438_resized.tif
# 438
# NDWI_Mask_438_resized_corrupt.tif
# Done
# NDWI_Mask_439_resized.tif
# 439
# NDWI_Mask_439_resized_corrupt.tif
# Done
# NDWI_Mask_442_resized.tif
# 442
# NDWI_Mask_442_resized_corrupt.tif
# Done
# NDWI_Mask_444_resized.tif
# 444
# NDWI_Mask_444_resized_corrupt.tif
# Done
# NDWI_Mask_445_resized.tif
# 445
# NDWI_Mask_445_resized_corrupt.tif
# 482
# NDWI_Mask_482_resized_corrupt.tif
# Done
# NDWI_Mask_483_resized.tif
# 483
# NDWI_Mask_483_resized_corrupt.tif
# Done
# NDWI_Mask_484_resized.tif
# 484
# NDWI_Mask_484_resized_corrupt.tif
# Done
# NDWI_Mask_485_resized.tif
# 485
# NDWI_Mask_485_resized_corrupt.tif
# Done
# NDWI_Mask_486_resized.tif
# 486
# NDWI_Mask_486_resized_corrupt.tif
# Done
# NDWI_Mask_487_resized.tif
# 487
# NDWI_Mask_487_resized_corrupt.tif
# Done
# NDWI_Mask_488_resized.tif
# 488
# NDWI_Mask_488_resized_corrupt.tif
# Done
# NDWI_Mask_490_resized.tif
# 490
# NDWI_Mask_490_resized_corrupt.tif
# Done
# NDWI_Mask_491_resized.tif
# 491
# NDWI_Mask_491_resized_corrupt.tif
# Done
# NDWI_Mask_492_resized.tif
# 492
# NDWI_Mask_492_resized_corrupt.tif
# Done
# NDWI_Mask_493_resized.tif
# 493
# NDWI_Mask_493_resized_corrupt.tif
# Done
# NDWI_Mask_494_resized.tif
# 494
# NDWI_Mask_494_resized_corrupt.tif
# Done
# NDWI_Mask_495_resized.tif
# 495
# NDWI_Mask_495_resized_corrupt.tif
# Done
# NDWI_Mask_496_resized.tif
# 496
# NDWI_Mask_496_resized_corrupt.tif
# Done
# NDWI_Mask_497_resized.tif
# 497
# NDWI_Mask_497_resized_corrupt.tif
# Done
# NDWI_Mask_498_resized.tif
# 498
# NDWI_Mask_498_resized_corrupt.tif
# Done
# NDWI_Mask_499_resized.tif
# 499
# NDWI_Mask_499_resized_corrupt.tif
# Done
# NDWI_Mask_49_resized.tif
# 49
# NDWI_Mask_49_resized_corrupt.tif
# Done
# NDWI_Mask_4_resized.tif
# 4
# NDWI_Mask_4_resized_corrupt.tif
# Done
# NDWI_Mask_501_resized.tif
# 501
# NDWI_Mask_501_resized_corrupt.tif
# Done
# NDWI_Mask_502_resized.tif
# 502
# NDWI_Mask_502_resized_corrupt.tif
# Done
# NDWI_Mask_503_resized.tif
# 503
# NDWI_Mask_503_resized_corrupt.tif
# Done
# NDWI_Mask_504_resized.tif
# 504
# NDWI_Mask_504_resized_corrupt.tif
# Done
# NDWI_Mask_505_resized.tif
# 505
# NDWI_Mask_505_resized_corrupt.tif
# Done
# NDWI_Mask_506_resized.tif
# 506
# NDWI_Mask_506_resized_corrupt.tif
# Done
# NDWI_Mask_507_resized.tif
# 507
# NDWI_Mask_507_resized_corrupt.tif
# Done
# NDWI_Mask_508_resized.tif
# 508
# NDWI_Mask_508_resized_corrupt.tif
# Done
# NDWI_Mask_509_resized.tif
# 509
# NDWI_Mask_509_resized_corrupt.tif
# Done
# NDWI_Mask_50_resized.tif
# 50
# NDWI_Mask_50_resized_corrupt.tif
# Done
# NDWI_Mask_510_resized.tif
# 510
# NDWI_Mask_510_resized_corrupt.tif
# Done
# NDWI_Mask_511_resized.tif
# 511
# NDWI_Mask_511_resized_corrupt.tif
# Done
# NDWI_Mask_512_resized.tif
# 512
# NDWI_Mask_512_resized_corrupt.tif
# NDWI_Mask_548_resized_corrupt.tif
# Done
# NDWI_Mask_549_resized.tif
# 549
# NDWI_Mask_549_resized_corrupt.tif
# Done
# NDWI_Mask_54_resized.tif
# 54
# NDWI_Mask_54_resized_corrupt.tif
# Done
# NDWI_Mask_550_resized.tif
# 550
# NDWI_Mask_550_resized_corrupt.tif
# Done
# NDWI_Mask_552_resized.tif
# 552
# NDWI_Mask_552_resized_corrupt.tif
# Done
# NDWI_Mask_553_resized.tif
# 553
# NDWI_Mask_553_resized_corrupt.tif
# Done
# NDWI_Mask_554_resized.tif
# 554
# NDWI_Mask_554_resized_corrupt.tif
# Done
# NDWI_Mask_555_resized.tif
# 555
# NDWI_Mask_555_resized_corrupt.tif
# Done
# NDWI_Mask_556_resized.tif
# 556
# NDWI_Mask_556_resized_corrupt.tif
# Done
# NDWI_Mask_558_resized.tif
# 558
# NDWI_Mask_558_resized_corrupt.tif
# Done
# NDWI_Mask_559_resized.tif
# 559
# NDWI_Mask_559_resized_corrupt.tif
# Done
# NDWI_Mask_55_resized.tif
# 55
# NDWI_Mask_55_resized_corrupt.tif
# Done
# NDWI_Mask_562_resized.tif
# 562
# NDWI_Mask_562_resized_corrupt.tif
# Done
# NDWI_Mask_563_resized.tif
# 563
# NDWI_Mask_563_resized_corrupt.tif
# Done
# NDWI_Mask_564_resized.tif
# 564
# NDWI_Mask_564_resized_corrupt.tif
# Done
# NDWI_Mask_565_resized.tif
# 565
# NDWI_Mask_565_resized_corrupt.tif
# Done
# NDWI_Mask_566_resized.tif
# 566
# NDWI_Mask_566_resized_corrupt.tif
# Done
# NDWI_Mask_567_resized.tif
# 567
# NDWI_Mask_567_resized_corrupt.tif
# Done
# NDWI_Mask_568_resized.tif
# 568
# NDWI_Mask_568_resized_corrupt.tif
# Done
# NDWI_Mask_569_resized.tif
# 569
# NDWI_Mask_569_resized_corrupt.tif
# Done
# NDWI_Mask_56_resized.tif
# 56
# NDWI_Mask_56_resized_corrupt.tif
# Done
# NDWI_Mask_570_resized.tif
# 570
# NDWI_Mask_570_resized_corrupt.tif
# Done
# NDWI_Mask_571_resized.tif
# 571
# NDWI_Mask_571_resized_corrupt.tif
# Done
# NDWI_Mask_572_resized.tif
# 572
# NDWI_Mask_572_resized_corrupt.tif
# Done
# NDWI_Mask_573_resized.tif
# 573
# NDWI_Mask_573_resized_corrupt.tif
# Done
# NDWI_Mask_574_resized.tif
# 574
# NDWI_Mask_574_resized_corrupt.tif
# Done
# NDWI_Mask_575_resized.tif
# 575
# NDWI_Mask_575_resized_corrupt.tif
# Done
# NDWI_Mask_576_resized.tif
# 576
# NDWI_Mask_576_resized_corrupt.tif
# Done
# NDWI_Mask_577_resized.tif
# 577
# NDWI_Mask_577_resized_corrupt.tif
# Done
# NDWI_Mask_578_resized.tif
# 578
# NDWI_Mask_578_resized_corrupt.tif
# Done
# NDWI_Mask_579_resized.tif
# 579
# NDWI_Mask_579_resized_corrupt.tif
# Done
# NDWI_Mask_57_resized.tif
# 57
# NDWI_Mask_57_resized_corrupt.tif
# Done
# NDWI_Mask_619_resized_corrupt.tif
# Done
# NDWI_Mask_620_resized.tif
# 620
# NDWI_Mask_620_resized_corrupt.tif
# Done
# NDWI_Mask_621_resized.tif
# 621
# NDWI_Mask_621_resized_corrupt.tif
# Done
# NDWI_Mask_622_resized.tif
# 622
# NDWI_Mask_622_resized_corrupt.tif
# Done
# NDWI_Mask_623_resized.tif
# 623
# NDWI_Mask_623_resized_corrupt.tif
# Done
# NDWI_Mask_624_resized.tif
# 624
# NDWI_Mask_624_resized_corrupt.tif
# Done
# NDWI_Mask_625_resized.tif
# 625
# NDWI_Mask_625_resized_corrupt.tif
# Done
# NDWI_Mask_626_resized.tif
# 626
# NDWI_Mask_626_resized_corrupt.tif
# Done
# NDWI_Mask_627_resized.tif
# 627
# NDWI_Mask_627_resized_corrupt.tif
# Done
# NDWI_Mask_628_resized.tif
# 628
# NDWI_Mask_628_resized_corrupt.tif
# Done
# NDWI_Mask_62_resized.tif
# 62
# NDWI_Mask_62_resized_corrupt.tif
# Done
# NDWI_Mask_630_resized.tif
# 630
# NDWI_Mask_630_resized_corrupt.tif
# Done
# NDWI_Mask_631_resized.tif
# 631
# NDWI_Mask_631_resized_corrupt.tif
# Done
# NDWI_Mask_632_resized.tif
# 632
# NDWI_Mask_632_resized_corrupt.tif
# Done
# NDWI_Mask_633_resized.tif
# 633
# NDWI_Mask_633_resized_corrupt.tif
# Done
# NDWI_Mask_634_resized.tif
# 634
# NDWI_Mask_634_resized_corrupt.tif
# Done
# NDWI_Mask_635_resized.tif
# 635
# NDWI_Mask_635_resized_corrupt.tif
# Done
# NDWI_Mask_636_resized.tif
# 636
# NDWI_Mask_636_resized_corrupt.tif
# Done
# NDWI_Mask_637_resized.tif
# 637
# NDWI_Mask_637_resized_corrupt.tif
# Done
# NDWI_Mask_638_resized.tif
# 638
# NDWI_Mask_638_resized_corrupt.tif
# Done
# NDWI_Mask_639_resized.tif
# 639
# ...
# 742
# NDWI_Mask_742_resized_corrupt.tif
# Done
# NDWI_Mask_743_resized.tif
# 743
# NDWI_Mask_743_resized_corrupt.tif
# Done
# NDWI_Mask_744_resized.tif
# 744
# NDWI_Mask_744_resized_corrupt.tif
# Done
# NDWI_Mask_745_resized.tif
# 745
# NDWI_Mask_745_resized_corrupt.tif
# Done
# NDWI_Mask_747_resized.tif
# 747
# NDWI_Mask_747_resized_corrupt.tif
# Done
# NDWI_Mask_748_resized.tif
# 748
# NDWI_Mask_748_resized_corrupt.tif
# Done
# NDWI_Mask_749_resized.tif
# 749
# NDWI_Mask_749_resized_corrupt.tif
# Done
# NDWI_Mask_74_resized.tif
# 74
# NDWI_Mask_74_resized_corrupt.tif
# Done
# NDWI_Mask_750_resized.tif
# 750
# NDWI_Mask_750_resized_corrupt.tif
# Done
# NDWI_Mask_751_resized.tif
# 751
# NDWI_Mask_751_resized_corrupt.tif
# Done
# NDWI_Mask_752_resized.tif
# 752
# NDWI_Mask_752_resized_corrupt.tif
# Done
# NDWI_Mask_753_resized.tif
# 753
# NDWI_Mask_753_resized_corrupt.tif
# Done
# NDWI_Mask_755_resized.tif
# 755
# NDWI_Mask_755_resized_corrupt.tif
# Done
# NDWI_Mask_756_resized.tif
# 756
# NDWI_Mask_756_resized_corrupt.tif
# Done
# NDWI_Mask_757_resized.tif
# 757
# NDWI_Mask_757_resized_corrupt.tif
# Done
# NDWI_Mask_758_resized.tif
# 758
# NDWI_Mask_758_resized_corrupt.tif
# Done
# NDWI_Mask_759_resized.tif
# 759
# NDWI_Mask_759_resized_corrupt.tif
# Done
# NDWI_Mask_75_resized.tif
# 75
# NDWI_Mask_75_resized_corrupt.tif
# Done
# NDWI_Mask_760_resized.tif
# 760
# NDWI_Mask_760_resized_corrupt.tif
# Done
# NDWI_Mask_761_resized.tif
# 761
# NDWI_Mask_761_resized_corrupt.tif
# Done
# NDWI_Mask_762_resized.tif
# 762
# NDWI_Mask_762_resized_corrupt.tif
# Done
# NDWI_Mask_764_resized.tif
# 764
# NDWI_Mask_764_resized_corrupt.tif
# Done
# NDWI_Mask_765_resized.tif
# 765
# NDWI_Mask_765_resized_corrupt.tif
# Done
# NDWI_Mask_766_resized.tif
# 766
# NDWI_Mask_766_resized_corrupt.tif
# Done
# NDWI_Mask_768_resized.tif
# 768
# NDWI_Mask_768_resized_corrupt.tif
# Done
# NDWI_Mask_769_resized.tif
# 769
# NDWI_Mask_769_resized_corrupt.tif
# Done
# NDWI_Mask_76_resized.tif
# 76
# NDWI_Mask_76_resized_corrupt.tif
# Done
# NDWI_Mask_772_resized.tif
# 772
# NDWI_Mask_772_resized_corrupt.tif
# Done
# NDWI_Mask_773_resized.tif
# 773
# NDWI_Mask_773_resized_corrupt.tif
# Done
# NDWI_Mask_774_resized.tif
# 774
# NDWI_Mask_774_resized_corrupt.tif
# Done
# NDWI_Mask_775_resized.tif
# 775
# NDWI_Mask_775_resized_corrupt.tif
# Done
# NDWI_Mask_776_resized.tif
# 776
# NDWI_Mask_776_resized_corrupt.tif
# Done
# NDWI_Mask_777_resized.tif
# 777
# NDWI_Mask_777_resized_corrupt.tif
# Done
# NDWI_Mask_778_resized.tif
# 778
# NDWI_Mask_778_resized_corrupt.tif
# Done
# NDWI_Mask_779_resized.tif
# 779
# NDWI_Mask_779_resized_corrupt.tif
# Done
# NDWI_Mask_77_resized.tif
# 77
# NDWI_Mask_77_resized_corrupt.tif
# Done
# NDWI_Mask_780_resized.tif
# 780
# NDWI_Mask_780_resized_corrupt.tif
# Done
# NDWI_Mask_781_resized.tif
# 781
# NDWI_Mask_781_resized_corrupt.tif
# Done
# NDWI_Mask_782_resized.tif
# 782
# NDWI_Mask_782_resized_corrupt.tif
# Done
# NDWI_Mask_784_resized.tif
# 784
# NDWI_Mask_784_resized_corrupt.tif
# Done
# NDWI_Mask_785_resized.tif
# 785
# NDWI_Mask_785_resized_corrupt.tif
# Done
# NDWI_Mask_786_resized.tif
# 786
# NDWI_Mask_786_resized_corrupt.tif
# Done
# NDWI_Mask_787_resized.tif
# 787
# NDWI_Mask_787_resized_corrupt.tif
# Done
# NDWI_Mask_788_resized.tif
# 788
# NDWI_Mask_788_resized_corrupt.tif
# Done
# NDWI_Mask_789_resized.tif
# 789
# NDWI_Mask_789_resized_corrupt.tif
# Done
# NDWI_Mask_791_resized.tif
# 791
# NDWI_Mask_791_resized_corrupt.tif
# Done
# NDWI_Mask_792_resized.tif
# 792
# NDWI_Mask_792_resized_corrupt.tif
# Done
# NDWI_Mask_794_resized.tif
# 794
# NDWI_Mask_794_resized_corrupt.tif
# Done
# NDWI_Mask_795_resized.tif
# 795
# NDWI_Mask_795_resized_corrupt.tif
# Done
# NDWI_Mask_796_resized.tif
# 796
# NDWI_Mask_796_resized_corrupt.tif
# Done
# NDWI_Mask_797_resized.tif
# 797
# NDWI_Mask_797_resized_corrupt.tif
# Done
# NDWI_Mask_799_resized.tif
# 799
# NDWI_Mask_799_resized_corrupt.tif
# Done
# NDWI_Mask_79_resized.tif
# 79
# NDWI_Mask_79_resized_corrupt.tif
# Done
# NDWI_Mask_7_resized.tif
# 7
# NDWI_Mask_7_resized_corrupt.tif
# Done
# NDWI_Mask_800_resized.tif
# 800
# NDWI_Mask_800_resized_corrupt.tif
# Done
# NDWI_Mask_801_resized.tif
# 801
# NDWI_Mask_801_resized_corrupt.tif
# Done
# NDWI_Mask_802_resized.tif
# 802
# NDWI_Mask_802_resized_corrupt.tif
# Done
# NDWI_Mask_803_resized.tif
# 803
# NDWI_Mask_803_resized_corrupt.tif
# Done
# NDWI_Mask_804_resized.tif
# 804
# NDWI_Mask_804_resized_corrupt.tif
# Done
# NDWI_Mask_805_resized.tif
# 805
# NDWI_Mask_805_resized_corrupt.tif
# Done
# NDWI_Mask_806_resized.tif
# 806
# NDWI_Mask_806_resized_corrupt.tif
# Done
# NDWI_Mask_809_resized.tif
# 809
# NDWI_Mask_809_resized_corrupt.tif
# Done
# NDWI_Mask_811_resized.tif
# 811
# NDWI_Mask_811_resized_corrupt.tif
# Done
# NDWI_Mask_812_resized.tif
# 812
# NDWI_Mask_812_resized_corrupt.tif
# Done
# NDWI_Mask_813_resized.tif
# 813
# NDWI_Mask_813_resized_corrupt.tif
# Done
# NDWI_Mask_815_resized.tif
# 815
# NDWI_Mask_815_resized_corrupt.tif
# Done
# NDWI_Mask_816_resized.tif
# 816
# NDWI_Mask_816_resized_corrupt.tif
# Done
# NDWI_Mask_817_resized.tif
# 817
# NDWI_Mask_817_resized_corrupt.tif
# Done
# NDWI_Mask_818_resized.tif
# 818
# NDWI_Mask_818_resized_corrupt.tif
# Done
# NDWI_Mask_819_resized.tif
# 819
# NDWI_Mask_819_resized_corrupt.tif
# Done
# NDWI_Mask_81_resized.tif
# 81
# NDWI_Mask_81_resized_corrupt.tif
# Done
# NDWI_Mask_820_resized.tif
# 820
# NDWI_Mask_820_resized_corrupt.tif
# Done
# NDWI_Mask_821_resized.tif
# 821
# NDWI_Mask_821_resized_corrupt.tif
# Done
# NDWI_Mask_822_resized.tif
# 822
# NDWI_Mask_822_resized_corrupt.tif
# Done
# NDWI_Mask_823_resized.tif
# 823
# NDWI_Mask_823_resized_corrupt.tif
# Done
# NDWI_Mask_824_resized.tif
# 824
# NDWI_Mask_824_resized_corrupt.tif
# Done
# NDWI_Mask_825_resized.tif
# 825
# NDWI_Mask_825_resized_corrupt.tif
# Done
# NDWI_Mask_826_resized.tif
# 826
# NDWI_Mask_826_resized_corrupt.tif
# Done
# NDWI_Mask_827_resized.tif
# 827
# NDWI_Mask_827_resized_corrupt.tif
# Done
# NDWI_Mask_828_resized.tif
# 828
# NDWI_Mask_828_resized_corrupt.tif
# Done
# NDWI_Mask_829_resized.tif
# 829
# NDWI_Mask_829_resized_corrupt.tif
# Done
# NDWI_Mask_82_resized.tif
# 82
# NDWI_Mask_82_resized_corrupt.tif
# Done
# NDWI_Mask_830_resized.tif
# 830
# NDWI_Mask_830_resized_corrupt.tif
# Done
# NDWI_Mask_831_resized.tif
# 831
# NDWI_Mask_831_resized_corrupt.tif
# Done
# NDWI_Mask_832_resized.tif
# 832
# NDWI_Mask_832_resized_corrupt.tif
# Done
# NDWI_Mask_833_resized.tif
# 833
# NDWI_Mask_833_resized_corrupt.tif
# Done
# NDWI_Mask_834_resized.tif
# 834
# NDWI_Mask_834_resized_corrupt.tif
# Done
# NDWI_Mask_835_resized.tif
# 835
# NDWI_Mask_835_resized_corrupt.tif
# Done
# NDWI_Mask_836_resized.tif
# 836
# NDWI_Mask_836_resized_corrupt.tif
# Done
# NDWI_Mask_839_resized.tif
# 839
# NDWI_Mask_839_resized_corrupt.tif
# Done
# NDWI_Mask_83_resized.tif
# 83
# NDWI_Mask_83_resized_corrupt.tif
# Done
# NDWI_Mask_840_resized.tif
# 840
# NDWI_Mask_840_resized_corrupt.tif
# Done
# NDWI_Mask_841_resized.tif
# 841
# NDWI_Mask_841_resized_corrupt.tif
# Done
# NDWI_Mask_842_resized.tif
# 842
# NDWI_Mask_842_resized_corrupt.tif
# Done
# NDWI_Mask_843_resized.tif
# 843
# NDWI_Mask_843_resized_corrupt.tif
# Done
# NDWI_Mask_844_resized.tif
# 844
# NDWI_Mask_844_resized_corrupt.tif
# Done
# NDWI_Mask_845_resized.tif
# 845
# NDWI_Mask_845_resized_corrupt.tif
# Done
# NDWI_Mask_849_resized.tif
# 849
# NDWI_Mask_849_resized_corrupt.tif
# Done
# NDWI_Mask_84_resized.tif
# 84
# NDWI_Mask_84_resized_corrupt.tif
# Done
# NDWI_Mask_850_resized.tif
# 850
# NDWI_Mask_850_resized_corrupt.tif
# Done
# NDWI_Mask_852_resized.tif
# 852
# NDWI_Mask_852_resized_corrupt.tif
# Done
# NDWI_Mask_853_resized.tif
# 853
# NDWI_Mask_853_resized_corrupt.tif
# Done
# NDWI_Mask_854_resized.tif
# 854
# NDWI_Mask_854_resized_corrupt.tif
# Done
# NDWI_Mask_855_resized.tif
# 855
# NDWI_Mask_855_resized_corrupt.tif
# Done
# NDWI_Mask_856_resized.tif
# 856
# NDWI_Mask_856_resized_corrupt.tif
# Done
# NDWI_Mask_857_resized.tif
# 857
# NDWI_Mask_857_resized_corrupt.tif
# Done
# NDWI_Mask_858_resized.tif
# 858
# NDWI_Mask_858_resized_corrupt.tif
# Done
# NDWI_Mask_859_resized.tif
# 859
# NDWI_Mask_859_resized_corrupt.tif
# Done
# NDWI_Mask_85_resized.tif
# 85
# NDWI_Mask_85_resized_corrupt.tif
# Done
# NDWI_Mask_861_resized.tif
# 861
# NDWI_Mask_861_resized_corrupt.tif
# Done
# NDWI_Mask_862_resized.tif
# 862
# NDWI_Mask_862_resized_corrupt.tif
# Done
# NDWI_Mask_863_resized.tif
# 863
# NDWI_Mask_863_resized_corrupt.tif
# Done
# NDWI_Mask_866_resized.tif
# 866
# NDWI_Mask_866_resized_corrupt.tif
# Done
# NDWI_Mask_867_resized.tif
# 867
# NDWI_Mask_867_resized_corrupt.tif
# Done
# NDWI_Mask_868_resized.tif
# 868
# NDWI_Mask_868_resized_corrupt.tif
# Done
# NDWI_Mask_869_resized.tif
# 869
# NDWI_Mask_869_resized_corrupt.tif
# Done
# NDWI_Mask_86_resized.tif
# 86
# NDWI_Mask_86_resized_corrupt.tif
# Done
# NDWI_Mask_870_resized.tif
# 870
# NDWI_Mask_870_resized_corrupt.tif
# Done
# NDWI_Mask_871_resized.tif
# 871
# NDWI_Mask_871_resized_corrupt.tif
# Done
# NDWI_Mask_872_resized.tif
# 872
# NDWI_Mask_872_resized_corrupt.tif
# Done
# NDWI_Mask_873_resized.tif
# 873
# NDWI_Mask_873_resized_corrupt.tif
# Done
# NDWI_Mask_874_resized.tif
# 874
# NDWI_Mask_874_resized_corrupt.tif
# Done
# NDWI_Mask_876_resized.tif
# 876
# NDWI_Mask_876_resized_corrupt.tif
# Done
# NDWI_Mask_877_resized.tif
# 877
# NDWI_Mask_877_resized_corrupt.tif
# Done
# NDWI_Mask_878_resized.tif
# 878
# NDWI_Mask_878_resized_corrupt.tif
# Done
# NDWI_Mask_87_resized.tif
# 87
# NDWI_Mask_87_resized_corrupt.tif
# Done
# NDWI_Mask_880_resized.tif
# 880
# NDWI_Mask_880_resized_corrupt.tif
# Done
# NDWI_Mask_881_resized.tif
# 881
# NDWI_Mask_881_resized_corrupt.tif
# Done
# NDWI_Mask_882_resized.tif
# 882
# NDWI_Mask_882_resized_corrupt.tif
# Done
# NDWI_Mask_884_resized.tif
# 884
# NDWI_Mask_884_resized_corrupt.tif
# Done
# NDWI_Mask_885_resized.tif
# 885
# NDWI_Mask_885_resized_corrupt.tif
# Done
# NDWI_Mask_886_resized.tif
# 886
# NDWI_Mask_886_resized_corrupt.tif
# Done
# NDWI_Mask_887_resized.tif
# 887
# NDWI_Mask_887_resized_corrupt.tif
# Done
# NDWI_Mask_888_resized.tif
# 888
# NDWI_Mask_888_resized_corrupt.tif
# Done
# NDWI_Mask_889_resized.tif
# 889
# NDWI_Mask_889_resized_corrupt.tif
# Done
# NDWI_Mask_891_resized.tif
# 891
# NDWI_Mask_891_resized_corrupt.tif
# Done
# NDWI_Mask_892_resized.tif
# 892
# NDWI_Mask_892_resized_corrupt.tif
# Done
# NDWI_Mask_894_resized.tif
# 894
# NDWI_Mask_894_resized_corrupt.tif
# Done
# NDWI_Mask_895_resized.tif
# 895
# NDWI_Mask_895_resized_corrupt.tif
# Done
# NDWI_Mask_896_resized.tif
# 896
# NDWI_Mask_896_resized_corrupt.tif
# Done
# NDWI_Mask_897_resized.tif
# 897
# NDWI_Mask_897_resized_corrupt.tif
# Done
# NDWI_Mask_898_resized.tif
# 898
# NDWI_Mask_898_resized_corrupt.tif
# Done
# NDWI_Mask_899_resized.tif
# 899
# NDWI_Mask_899_resized_corrupt.tif
# Done
# NDWI_Mask_89_resized.tif
# 89
# NDWI_Mask_89_resized_corrupt.tif
# Done
# NDWI_Mask_901_resized.tif
# 901
# NDWI_Mask_901_resized_corrupt.tif
# Done
# NDWI_Mask_902_resized.tif
# 902
# NDWI_Mask_902_resized_corrupt.tif
# Done
# NDWI_Mask_903_resized.tif
# 903
# NDWI_Mask_903_resized_corrupt.tif
# Done
# NDWI_Mask_904_resized.tif
# 904
# NDWI_Mask_904_resized_corrupt.tif
# Done
# NDWI_Mask_905_resized.tif
# 905
# NDWI_Mask_905_resized_corrupt.tif
# Done
# NDWI_Mask_906_resized.tif
# 906
# NDWI_Mask_906_resized_corrupt.tif
# Done
# NDWI_Mask_907_resized.tif
# 907
# NDWI_Mask_907_resized_corrupt.tif
# Done
# NDWI_Mask_908_resized.tif
# 908
# NDWI_Mask_908_resized_corrupt.tif
# Done
# NDWI_Mask_909_resized.tif
# 909
# NDWI_Mask_909_resized_corrupt.tif
# Done
# NDWI_Mask_90_resized.tif
# 90
# NDWI_Mask_90_resized_corrupt.tif
# Done
# NDWI_Mask_910_resized.tif
# 910
# NDWI_Mask_910_resized_corrupt.tif
# Done
# NDWI_Mask_912_resized.tif
# 912
# NDWI_Mask_912_resized_corrupt.tif
# Done
# NDWI_Mask_913_resized.tif
# 913
# NDWI_Mask_913_resized_corrupt.tif
# Done
# NDWI_Mask_915_resized.tif
# 915
# NDWI_Mask_915_resized_corrupt.tif
# Done
# NDWI_Mask_916_resized.tif
# 916
# NDWI_Mask_916_resized_corrupt.tif
# Done
# NDWI_Mask_917_resized.tif
# 917
# NDWI_Mask_917_resized_corrupt.tif
# Done
# NDWI_Mask_919_resized.tif
# 919
# NDWI_Mask_919_resized_corrupt.tif
# Done
# NDWI_Mask_920_resized.tif
# 920
# NDWI_Mask_920_resized_corrupt.tif
# Done
# NDWI_Mask_921_resized.tif
# 921
# NDWI_Mask_921_resized_corrupt.tif
# Done
# NDWI_Mask_922_resized.tif
# 922
# NDWI_Mask_922_resized_corrupt.tif
# Done
# NDWI_Mask_923_resized.tif
# 923
# NDWI_Mask_923_resized_corrupt.tif
# Done
# NDWI_Mask_924_resized.tif
# 924
# NDWI_Mask_924_resized_corrupt.tif
# Done
# NDWI_Mask_926_resized.tif
# 926
# NDWI_Mask_926_resized_corrupt.tif
# Done
# NDWI_Mask_927_resized.tif
# 927
# NDWI_Mask_927_resized_corrupt.tif
# Done
# NDWI_Mask_929_resized.tif
# 929
# NDWI_Mask_929_resized_corrupt.tif
# Done
# NDWI_Mask_92_resized.tif
# 92
# NDWI_Mask_92_resized_corrupt.tif
# Done
# NDWI_Mask_932_resized.tif
# 932
# NDWI_Mask_932_resized_corrupt.tif
# Done
# NDWI_Mask_933_resized.tif
# 933
# NDWI_Mask_933_resized_corrupt.tif
# Done
# NDWI_Mask_934_resized.tif
# 934
# NDWI_Mask_934_resized_corrupt.tif
# Done
# NDWI_Mask_935_resized.tif
# 935
# NDWI_Mask_935_resized_corrupt.tif
# Done
# NDWI_Mask_936_resized.tif
# 936
# NDWI_Mask_936_resized_corrupt.tif
# Done
# NDWI_Mask_937_resized.tif
# 937
# NDWI_Mask_937_resized_corrupt.tif
# Done
# NDWI_Mask_939_resized.tif
# 939
# NDWI_Mask_939_resized_corrupt.tif
# Done
# NDWI_Mask_940_resized.tif
# 940
# NDWI_Mask_940_resized_corrupt.tif
# Done
# NDWI_Mask_942_resized.tif
# 942
# NDWI_Mask_942_resized_corrupt.tif
# Done
# NDWI_Mask_943_resized.tif
# 943
# NDWI_Mask_943_resized_corrupt.tif
# Done
# NDWI_Mask_944_resized.tif
# 944
# NDWI_Mask_944_resized_corrupt.tif
# Done
# NDWI_Mask_945_resized.tif
# 945
# NDWI_Mask_945_resized_corrupt.tif
# Done
# NDWI_Mask_946_resized.tif
# 946
# NDWI_Mask_946_resized_corrupt.tif
# Done
# NDWI_Mask_947_resized.tif
# 947
# NDWI_Mask_947_resized_corrupt.tif
# Done
# NDWI_Mask_949_resized.tif
# 949
# NDWI_Mask_949_resized_corrupt.tif
# Done
# NDWI_Mask_94_resized.tif
# 94
# NDWI_Mask_94_resized_corrupt.tif
# Done
# NDWI_Mask_951_resized.tif
# 951
# NDWI_Mask_951_resized_corrupt.tif
# Done
# NDWI_Mask_952_resized.tif
# 952
# NDWI_Mask_952_resized_corrupt.tif
# Done
# NDWI_Mask_953_resized.tif
# 953
# NDWI_Mask_953_resized_corrupt.tif
# Done
# NDWI_Mask_954_resized.tif
# 954
# NDWI_Mask_954_resized_corrupt.tif
# Done
# NDWI_Mask_956_resized.tif
# 956
# NDWI_Mask_956_resized_corrupt.tif
# Done
# NDWI_Mask_958_resized.tif
# 958
# NDWI_Mask_958_resized_corrupt.tif
# Done
# NDWI_Mask_959_resized.tif
# 959
# NDWI_Mask_959_resized_corrupt.tif
# Done
# NDWI_Mask_961_resized.tif
# 961
# NDWI_Mask_961_resized_corrupt.tif
# Done
# NDWI_Mask_962_resized.tif
# 962
# NDWI_Mask_962_resized_corrupt.tif
# Done
# NDWI_Mask_963_resized.tif
# 963
# NDWI_Mask_963_resized_corrupt.tif
# Done
# NDWI_Mask_964_resized.tif
# 964
# NDWI_Mask_964_resized_corrupt.tif
# Done
# NDWI_Mask_965_resized.tif
# 965
# NDWI_Mask_965_resized_corrupt.tif
# Done
# NDWI_Mask_966_resized.tif
# 966
# NDWI_Mask_966_resized_corrupt.tif
# Done
# NDWI_Mask_967_resized.tif
# 967
# NDWI_Mask_967_resized_corrupt.tif
# Done
# NDWI_Mask_968_resized.tif
# 968
# NDWI_Mask_968_resized_corrupt.tif
# Done
# NDWI_Mask_969_resized.tif
# 969
# NDWI_Mask_969_resized_corrupt.tif
# Done
# NDWI_Mask_96_resized.tif
# 96
# NDWI_Mask_96_resized_corrupt.tif
# Done
# NDWI_Mask_970_resized.tif
# 970
# NDWI_Mask_970_resized_corrupt.tif
# Done
# NDWI_Mask_971_resized.tif
# 971
# NDWI_Mask_971_resized_corrupt.tif
# Done
# NDWI_Mask_972_resized.tif
# 972
# NDWI_Mask_972_resized_corrupt.tif
# Done
# NDWI_Mask_973_resized.tif
# 973
# NDWI_Mask_973_resized_corrupt.tif
# Done
# NDWI_Mask_975_resized.tif
# 975
# NDWI_Mask_975_resized_corrupt.tif
# Done
# NDWI_Mask_976_resized.tif
# 976
# NDWI_Mask_976_resized_corrupt.tif
# Done
# NDWI_Mask_977_resized.tif
# 977
# NDWI_Mask_977_resized_corrupt.tif
# Done
# NDWI_Mask_978_resized.tif
# 978
# NDWI_Mask_978_resized_corrupt.tif
# Done
# NDWI_Mask_979_resized.tif
# 979
# NDWI_Mask_979_resized_corrupt.tif
# Done
# NDWI_Mask_97_resized.tif
# 97
# NDWI_Mask_97_resized_corrupt.tif
# Done
# NDWI_Mask_980_resized.tif
# 980
# NDWI_Mask_980_resized_corrupt.tif
# Done
# NDWI_Mask_981_resized.tif
# 981
# NDWI_Mask_981_resized_corrupt.tif
# Done
# NDWI_Mask_982_resized.tif
# 982
# NDWI_Mask_982_resized_corrupt.tif
# Done
# NDWI_Mask_984_resized.tif
# 984
# NDWI_Mask_984_resized_corrupt.tif
# Done
# NDWI_Mask_985_resized.tif
# 985
# NDWI_Mask_985_resized_corrupt.tif
# Done
# NDWI_Mask_987_resized.tif
# 987
# NDWI_Mask_987_resized_corrupt.tif
# Done
# NDWI_Mask_988_resized.tif
# 988
# NDWI_Mask_988_resized_corrupt.tif
# Done
# NDWI_Mask_989_resized.tif
# 989
# NDWI_Mask_989_resized_corrupt.tif
# Done
# NDWI_Mask_98_resized.tif
# 98
# NDWI_Mask_98_resized_corrupt.tif
# Done
# NDWI_Mask_990_resized.tif
# 990
# NDWI_Mask_990_resized_corrupt.tif
# Done
# NDWI_Mask_991_resized.tif
# 991
# NDWI_Mask_991_resized_corrupt.tif
# Done
# NDWI_Mask_992_resized.tif
# 992
# NDWI_Mask_992_resized_corrupt.tif
# Done
# NDWI_Mask_993_resized.tif
# 993
# NDWI_Mask_993_resized_corrupt.tif
# Done
# NDWI_Mask_994_resized.tif
# 994
# NDWI_Mask_994_resized_corrupt.tif
# Done
# NDWI_Mask_995_resized.tif
# 995
# NDWI_Mask_995_resized_corrupt.tif
# Done
# NDWI_Mask_996_resized.tif
# 996
# NDWI_Mask_996_resized_corrupt.tif
# Done
# NDWI_Mask_997_resized.tif
# 997
# NDWI_Mask_997_resized_corrupt.tif
# Done
# NDWI_Mask_998_resized.tif
# 998
# NDWI_Mask_998_resized_corrupt.tif
# Done
# NDWI_Mask_999_resized.tif
# 999
# NDWI_Mask_999_resized_corrupt.tif
# Done
# NDWI_Mask_99_resized.tif
# 99
# NDWI_Mask_99_resized_corrupt.tif
# Done
