# %% [markdown]
# ## Sentinel-1 SAR preprocessing pipeline
#
# Sentinel-1 Ground Range Detected (GRD) products are acquired using the
# Alaska Satellite Facility (ASF) API and processed through a standardized
# SAR preprocessing pipeline to ensure radiometric, geometric, and spatial
# consistency across all images.
#
# First, precise orbit files (Sentinel Precise) are applied using a polynomial
# degree of 3 to correct satellite positioning errors and improve geolocation
# accuracy. This step reduces orbit-related distortions and ensures reliable
# pixel-level alignment across acquisitions.
#
# Next, radiometric calibration is performed to convert raw digital numbers
# into physically meaningful backscatter coefficients. Specifically, σ⁰
# (backscatter) values are generated for both VV and VH polarizations using
# linear (non-dB) scaling. This normalization step compensates for variations
# in sensor acquisition geometry and illumination conditions, enabling
# consistent comparison across scenes.
#
# To mitigate the effect of multiplicative speckle noise inherent to SAR
# imagery, speckle filtering is applied using the Lee filter with a 5×5 window.
# The filter is configured with a damping factor of 2 and adaptive estimation
# of the equivalent number of looks (ENL). Additional constraints
# (target window size of 3×3, σ = 0.9, and analysis window size of 50) are
# used to preserve structural details while reducing noise.
#
# Finally, geometric distortions caused by terrain-induced foreshortening,
# layover, and shadow effects are corrected using Range Doppler Terrain
# Correction. This step is performed using the SRTM 3 Arc-Second Digital
# Elevation Model (DEM) and resampled to a 10 m pixel spacing, ensuring
# spatial alignment with ground coordinates and downstream annotations.

# %%
# %matplotlib inline
import numpy as np
import os
import snappy
from snappy import Product, ProductIO, HashMap, GPF

# For shapefiles
# import shapefile
# import pygeoif
filename = 'S1A_IW_GRDH_1SDV_20240117T085136_20240117T085201_052144_064D8C_6097.SAFE'
path_to_sentinel_data = "./data/" + filename + ".zip"
product = ProductIO.readProduct(path_to_sentinel_data)

# %%
width = product.getSceneRasterWidth()
print("Width: {} px".format(width))
height = product.getSceneRasterHeight()
print("Height: {} px".format(height))
name = product.getName()
print("Name: {}".format(name))
band_names = product.getBandNames()
print("Band names: {}".format(", ".join(band_names)))
# Out:
# Width: 25972 px
# Height: 16834 px
# Name: S1A_IW_GRDH_1SDV_20240117T085136_20240117T085201_052144_064D8C_6097
# Band names: Amplitude_VH, Intensity_VH, Amplitude_VV, Intensity_VV

# %%
parameters = HashMap()
GPF.getDefaultInstance().getOperatorSpiRegistry().loadOperatorSpis()
parameters.put('orbitType', 'Sentinel Precise (Auto Download)')
parameters.put('polyDegree', '3')
parameters.put('continueOnFail', 'false')

apply_orbit_file = GPF.createProduct('Apply-Orbit-File', parameters, product)

# %%
width = apply_orbit_file.getSceneRasterWidth()
print("Width: {} px".format(width))
height = apply_orbit_file.getSceneRasterHeight()
print("Height: {} px".format(height))
band_names = apply_orbit_file.getBandNames()
print("Band names: {}".format(", ".join(band_names)))
# Out:
# Width: 25972 px
# Height: 16834 px
# Band names: Amplitude_VH, Intensity_VH, Amplitude_VV, Intensity_VV

# %%
parameters = HashMap()
parameters.put('outputSigmaBand', True)
parameters.put('sourceBands', 'Intensity_VV,Intensity_VH')
parameters.put('selectedPolarisations', "VV,VH")
# parameters.put('sourceBands', 'Intensity_VH')
# parameters.put('selectedPolarisations', "VH")
parameters.put('outputImageScaleInDb', False)

product_calibrated = GPF.createProduct("Calibration", parameters, apply_orbit_file)

# %%
width = product_calibrated.getSceneRasterWidth()
print("Width: {} px".format(width))
height = product_calibrated.getSceneRasterHeight()
print("Height: {} px".format(height))
band_names = product_calibrated.getBandNames()
print("Band names: {}".format(", ".join(band_names)))
# Out:
# Width: 25972 px
# Height: 16834 px
# Band names: Sigma0_VV, Sigma0_VH

# %%
filterSizeY = '5'
filterSizeX = '5'
parameters = HashMap()
# parameters.put('sourceBands', 'Sigma0_VV')
parameters.put('filter', 'Lee')
parameters.put('filterSizeX', filterSizeX)
parameters.put('filterSizeY', filterSizeY)
parameters.put('dampingFactor', '2')
parameters.put('estimateENL', 'true')
parameters.put('enl', '1.0')
parameters.put('numLooksStr', '1')
parameters.put('targetWindowSizeStr', '3x3')
parameters.put('sigmaStr', '0.9')
parameters.put('anSize', '50')
speckle_filter = GPF.createProduct('Speckle-Filter', parameters,product_calibrated)

# %%
width = speckle_filter.getSceneRasterWidth()
print("Width: {} px".format(width))
height = speckle_filter.getSceneRasterHeight()
print("Height: {} px".format(height))
band_names = speckle_filter.getBandNames()
print("Band names: {}".format(", ".join(band_names)))
# Out:
# Width: 25972 px
# Height: 16834 px
# Band names: Sigma0_VV, Sigma0_VH

# %%
parameters = HashMap()
parameters.put('demName', 'SRTM 3Sec')
parameters.put('pixelSpacingInMeter', 10.0)
# parameters.put('sourceBands', 'Sigma0_VV')
speckle_filter_tc = GPF.createProduct("Terrain-Correction", parameters, speckle_filter)

# %%
width = speckle_filter_tc.getSceneRasterWidth()
print("Width: {} px".format(width))
height = speckle_filter_tc.getSceneRasterHeight()
print("Height: {} px".format(height))
band_names = speckle_filter_tc.getBandNames()
print("Band names: {}".format(", ".join(band_names)))
# Out:
# Width: 29281 px
# Height: 22515 px
# Band names: Sigma0_VV, Sigma0_VH

# %%
ProductIO.writeProduct(speckle_filter_tc, f"./data/final_{filename}", 'BEAM-DIMAP')
os.path.exists(f"./data/final_{filename}.dim")
# Out:
# True
